# %%
import pandas as pd

file_url = 'https://raw.githubusercontent.com/YufanPeter/EPL_Analysis/refs/heads/main/EPL_data.csv'

df = pd.read_csv(file_url)

df["Attendance"] = (df["Attendance"].str.replace(",", "", regex=False).astype(float))

print(df.columns)
# Out:
# Index(['Season', 'Team', 'Venue', 'Result', 'GF (goals for)',
#        'GA (goals against)', 'Opponent', 'CrdY', 'CrdR', '2CrdY',
#        'Fls (fouls committed)', 'Fld (fouls drawn)', 'Off (offsides)',
#        'Crs (crosses)', 'Int (interceptions)', 'TklW (tackles won)',
#        'Pkwon (penalty kicks won)', 'Pkcon (penalty kicks conceded)',
#        'OG (own goals)', 'Recov (ball recoveries)', 'Won (aerials won)',
#        'Lost', 'Won%', 'xG (expected goals)', 'xGA (expected goals allowed)',
#        'Poss (possession)', 'Attendance', 'Referee', 'Referee Hometown'],
#       dtype='object')

# %%
# A dictionary to map inconsistent or abbreviated opponent team names to standardized format
opponent_team = {
    "Burnley": "Burnley",
    "Newcastle Utd": "Newcastle United",
    "Sheffield Utd": "Sheffield United",
    "Fulham": "Fulham",
    "West Ham": "West Ham United",
    "Nott'ham Forest": "Nottingham Forest",
    "Wolves": "Wolverhampton Wanderers",
    "Arsenal": "Arsenal",
    "Brighton": "Brighton & Hove Albion",
    "Manchester Utd": "Manchester United",
    "Bournemouth": "Bournemouth",
    "Chelsea": "Chelsea",
    "Liverpool": "Liverpool",
    "Tottenham": "Tottenham Hotspur",
    "Aston Villa": "Aston Villa",
    "Luton Town": "Luton Town",
    "Crystal Palace": "Crystal Palace",
    "Everton": "Everton",
    "Brentford": "Brentford",
    "Manchester City": "Manchester City",
    "Southampton": "Southampton",
    "Leicester City": "Leicester City",
    "Leeds United": "Leeds United",
    "Norwich City": "Norwich City",
    "Watford": "Watford",
    "West Brom": "West Bromwich Albion",
    "Huddersfield": "Huddersfield Town",
    "Cardiff City": "Cardiff City",
    "Stoke City": "Stoke City",
    "Swansea City": "Swansea City",
    "Hull City": "Hull City",
    "Middlesbrough": "Middlesbrough",
    "Sunderland": "Sunderland",
    "QPR": "Queens Park Rangers"
}

df["Opponent"] = df["Opponent"].map(opponent_team)

print("Done")
# Out:
# Done

# %%
print(df['Team'].unique())
# Out:
# ['Manchester City' 'Arsenal' 'Liverpool' 'Aston Villa' 'Tottenham Hotspur'
#  'Chelsea' 'Newcastle United' 'Manchester United' 'West Ham United'
#  'Crystal Palace' 'Brighton & Hove Albion' 'Bournemouth' 'Fulham'
#  'Wolverhampton Wanderers' 'Everton' 'Brentford' 'Nottingham Forest'
#  'Luton Town' 'Burnley' 'Sheffield United' 'Leicester City' 'Leeds United'
#  'Southampton' 'Watford' 'Norwich City' 'West Bromwich Albion'
#  'Cardiff City' 'Huddersfield Town' 'Swansea City' 'Stoke City'
#  'Hull City' 'Middlesbrough' 'Sunderland' 'Queens Park Rangers']

# %%
print(df[['Referee', 'Referee Hometown']].drop_duplicates())
# Out:
#                 Referee                                 Referee Hometown
# 0          Craig Pawson                               Sheffield, England
# 1          Robert Jones                              Merseyside, England
# 2        Jarred Gillett                Gold Coast, Queensland, Australia
# 3        Michael Oliver                        Ashington, Northumberland
# 4           Andy Madley                          Huddersfield, Yorkshire
# 5        Anthony Taylor                          Wythenshawe, Manchester
# 9          Paul Tierney                        Wigan, Greater Manchester
# 12       Chris Kavanagh                              Manchester, England
# 13         Simon Hooper                                 Swindon, England
# 14          John Brooks          Melton Mowbray, Leicestershire, England
# 15         Tim Robinson                                      West Sussex
# 18          David Coote                         Nottinghamshire, England
# ...

# %%
# A dictionary to map referee names to their detailed hometown
referee_detailed_region = {
    "Craig Pawson": "South Yorkshire",
    "Robert Jones": "Merseyside",
    "Jarred Gillett": "Outside UK",
    "Michael Oliver": "Tyne and Wear",
    "Andy Madley": "West Yorkshire",
    "Anthony Taylor": "Greater Manchester",
    "Paul Tierney": "Greater Manchester",
    "Chris Kavanagh": "Greater Manchester",
    "Simon Hooper": "South of England",
    "John Brooks": "Middle England",
    "Tim Robinson": "South of England",
    "David Coote": "Middle England",
    "Samuel Barrott": "West Yorkshire",
    "Darren England": "South Yorkshire",
    "Michael Salisbury": "North west of England",
    "Stuart Attwell": "Middle England",
    "Peter Bankes": "Merseyside",
    "Joshua Smith": "East of England",
    "Thomas Bramall": "South Yorkshire",
    "Lewis Smith": "North west of England",
    "Darren Bond": "North west of England",
    "Tony Harrington": "North east of England",
    "Samuel Allison": "South of England",
    "Graham Scott": "South of England",
    "Sunny Singh": "Middle England",
    "Robert Madley": "West Yorkshire",
    "Rebecca Welch": "Tyne and Wear",
    "Matt Donohue": "Greater Manchester",
    "Andre Marriner": "West Midlands",
    "Martin Atkinson": "West Yorkshire",
    "Jonathan Moss": "Tyne and Wear",
    "Kevin Friend": "Middle England",
    "Mike Dean": "Merseyside",
    "Lee Mason": "Greater Manchester",
    "Oliver Langford": "West Midlands",
    "Lee Probert": "South of England",
    "Roger East": "South of England",
    "Niel Swarbrick": "North west of England",
    "Mike Jones": "North west of England",
    "Mark Clattenburg": "Tyne and Wear",
    "Keith Stroud": "South of England",
    "Philip Dowd": "Middle England",
    "Chris Foy": "North west of England",
    "Mark Jones": "North west of England"
}


df["Referee Hometown"] = df["Referee"].map(referee_detailed_region)

print(df.head())
# Out:
#    Season             Team Venue Result  GF (goals for)  GA (goals against)  \
# 0       1  Manchester City  Away      W               3                   0
# 1       1  Manchester City  Home      W               1                   0
# 2       1  Manchester City  Away      W               2                   1
# 3       1  Manchester City  Home      W               5                   1
# 4       1  Manchester City  Away      W               3                   1
#
#            Opponent  CrdY  CrdR  2CrdY  ...  Recov (ball recoveries)  \
# 0           Burnley     0     0      0  ...                     54.0
# 1  Newcastle United     1     0      0  ...                     54.0
# 2  Sheffield United     0     0      0  ...                     53.0
# 3            Fulham     2     0      0  ...                     46.0
# 4   West Ham United     2     0      0  ...                     43.0
#
#    Won (aerials won)  Lost  Won%  xG (expected goals)  \
# ...

# %%
# A dictionary to map referee names to their broad hometowns
referee_broad_region = {
    "Craig Pawson": "North England",
    "Robert Jones": "North England",
    "Jarred Gillett": "Other",
    "Michael Oliver": "North England",
    "Andy Madley": "North England",
    "Anthony Taylor": "North England",
    "Paul Tierney": "North England",
    "Chris Kavanagh": "North England",
    "Simon Hooper": "South England",
    "John Brooks": "Midlands",
    "Tim Robinson": "South England",
    "David Coote": "Midlands",
    "Samuel Barrott": "North England",
    "Darren England": "North England",
    "Michael Salisbury": "North England",
    "Stuart Attwell": "Midlands",
    "Peter Bankes": "North England",
    "Joshua Smith": "Midlands",
    "Thomas Bramall": "North England",
    "Lewis Smith": "North England",
    "Darren Bond": "North England",
    "Tony Harrington": "North England",
    "Samuel Allison": "South England",
    "Graham Scott": "South England",
    "Sunny Singh": "Midlands",
    "Robert Madley": "North England",
    "Rebecca Welch": "North England",
    "Matt Donohue": "North England",
    "Andre Marriner": "Midlands",
    "Martin Atkinson": "North England",
    "Jonathan Moss": "North England",
    "Kevin Friend": "Midlands",
    "Mike Dean": "North England",
    "Lee Mason": "North England",
    "Oliver Langford": "Midlands",
    "Lee Probert": "South England",
    "Roger East": "South England",
    "Niel Swarbrick": "North England",
    "Mike Jones": "North England",
    "Mark Clattenburg": "North England",
    "Keith Stroud": "South England",
    "Philip Dowd": "Midlands",
    "Chris Foy": "North England",
    "Mark Jones": "North England"
}

df["Referee Broad Region"] = df["Referee"].map(referee_broad_region)

print(df.head())
# Out:
#    Season             Team Venue Result  GF (goals for)  GA (goals against)  \
# 0       1  Manchester City  Away      W               3                   0
# 1       1  Manchester City  Home      W               1                   0
# 2       1  Manchester City  Away      W               2                   1
# 3       1  Manchester City  Home      W               5                   1
# 4       1  Manchester City  Away      W               3                   1
#
#            Opponent  CrdY  CrdR  2CrdY  ...  Won (aerials won)  Lost  Won%  \
# 0           Burnley     0     0      0  ...               13.0  13.0  50.0
# 1  Newcastle United     1     0      0  ...                3.0   6.0  33.3
# 2  Sheffield United     0     0      0  ...               12.0   5.0  70.6
# 3            Fulham     2     0      0  ...                8.0   6.0  57.1
# 4   West Ham United     2     0      0  ...                8.0  12.0  40.0
#
# ...

# %%
# A dictionary to map teams in EPL to their detailed regions (same as the detailed hometown of referee)
team_detailed_region = {
    'Manchester City': 'Greater Manchester',
    'Manchester United': 'Greater Manchester',
    'Liverpool': 'Merseyside',
    'Everton': 'Merseyside',
    'Sheffield United': 'South Yorkshire',
    'Newcastle United': 'Tyne and Wear',
    'Sunderland': 'Tyne and Wear',
    'Aston Villa': 'West Midlands',
    'Wolverhampton Wanderers': 'West Midlands',
    'West Bromwich Albion': 'West Midlands',
    'Leeds United': 'West Yorkshire',
    'Huddersfield Town': 'West Yorkshire',
    'West Ham United': 'London',
    'Chelsea': 'London',
    'Fulham': 'London',
    'Brentford': 'London',
    'Arsenal': 'London',
    'Tottenham Hotspur': 'London',
    'Crystal Palace': 'London',
    'Queens Park Rangers': 'London',
    'Brighton & Hove Albion': 'South of England',
    'Bournemouth': 'South of England',
    'Southampton': 'South of England',
    'Watford': 'East of England',
    'Norwich City': 'East of England',
    'Luton Town': 'East of England',
    'Burnley': 'North west of England',
    'Nottingham Forest': 'Middle England',
    'Leicester City': 'Middle England',
    'Stoke City': 'Middle England',
    'Middlesbrough': 'North east of England',
    'Hull City': 'East of England',
    'Cardiff City': 'Wales',
    'Swansea City': 'Wales'
}

df["Team Detailed Region"] = df["Team"].map(team_detailed_region)

print(df.head())
# Out:
#    Season             Team Venue Result  GF (goals for)  GA (goals against)  \
# 0       1  Manchester City  Away      W               3                   0
# 1       1  Manchester City  Home      W               1                   0
# 2       1  Manchester City  Away      W               2                   1
# 3       1  Manchester City  Home      W               5                   1
# 4       1  Manchester City  Away      W               3                   1
#
#            Opponent  CrdY  CrdR  2CrdY  ...  Lost  Won%  xG (expected goals)  \
# 0           Burnley     0     0      0  ...  13.0  50.0                  1.9
# 1  Newcastle United     1     0      0  ...   6.0  33.3                  1.0
# 2  Sheffield United     0     0      0  ...   5.0  70.6                  3.5
# 3            Fulham     2     0      0  ...   6.0  57.1                  2.2
# 4   West Ham United     2     0      0  ...  12.0  40.0                  3.6
#
# ...

# %%
# A dictionary to map teams in EPL to their broad regions (same as the broad hometown of referee)
team_region = {
    "Manchester City": "North England",
    "Arsenal": "South England",
    "Liverpool": "North England",
    "Aston Villa": "Midlands",
    "Tottenham Hotspur": "South England",
    "Chelsea": "South England",
    "Newcastle United": "North England",
    "Manchester United": "North England",
    "West Ham United": "South England",
    "Crystal Palace": "South England",
    "Brighton & Hove Albion": "South England",
    "Bournemouth": "South England",
    "Fulham": "South England",
    "Wolverhampton Wanderers": "Midlands",
    "Everton": "North England",
    "Brentford": "South England",
    "Nottingham Forest": "Midlands",
    "Luton Town": "South England",
    "Burnley": "North England",
    "Sheffield United": "North England",
    "Leicester City": "Midlands",
    "Leeds United": "North England",
    "Southampton": "South England",
    "Watford": "South England",
    "Norwich City": "South England",
    "West Bromwich Albion": "Midlands",
    "Cardiff City": "Wales",
    "Huddersfield Town": "North England",
    "Swansea City": "Wales",
    "Stoke City": "Midlands",
    "Hull City": "North England",
    "Middlesbrough": "North England",
    "Sunderland": "North England",
    "Queens Park Rangers": "South England"
}

df["Team Region"] = df["Team"].map(team_region)

print(df.head())
# Out:
#    Season             Team Venue Result  GF (goals for)  GA (goals against)  \
# 0       1  Manchester City  Away      W               3                   0
# 1       1  Manchester City  Home      W               1                   0
# 2       1  Manchester City  Away      W               2                   1
# 3       1  Manchester City  Home      W               5                   1
# 4       1  Manchester City  Away      W               3                   1
#
#            Opponent  CrdY  CrdR  2CrdY  ...  Won%  xG (expected goals)  \
# 0           Burnley     0     0      0  ...  50.0                  1.9
# 1  Newcastle United     1     0      0  ...  33.3                  1.0
# 2  Sheffield United     0     0      0  ...  70.6                  3.5
# 3            Fulham     2     0      0  ...  57.1                  2.2
# 4   West Ham United     2     0      0  ...  40.0                  3.6
#
#    xGA (expected goals allowed)  Poss (possession)  Attendance  \
# ...

# %%
# A dictionary to map opponent teams in EPL to their detailed region (same as the detailed hometown of referee)
# Actually haven't been used in the code
opponent_detailed_region = {
    'Manchester City': 'Greater Manchester',
    'Manchester United': 'Greater Manchester',
    'Liverpool': 'Merseyside',
    'Everton': 'Merseyside',
    'Sheffield United': 'South Yorkshire',
    'Newcastle United': 'Tyne and Wear',
    'Sunderland': 'Tyne and Wear',
    'Aston Villa': 'West Midlands',
    'Wolverhampton Wanderers': 'West Midlands',
    'West Bromwich Albion': 'West Midlands',
    'Leeds United': 'West Yorkshire',
    'Huddersfield Town': 'West Yorkshire',
    'West Ham United': 'London',
    'Chelsea': 'London',
    'Fulham': 'London',
    'Brentford': 'London',
    'Arsenal': 'London',
    'Tottenham Hotspur': 'London',
    'Crystal Palace': 'London',
    'Queens Park Rangers': 'London',
    'Brighton & Hove Albion': 'South of England',
    'Bournemouth': 'South of England',
    'Southampton': 'South of England',
    'Watford': 'East of England',
    'Norwich City': 'East of England',
    'Luton Town': 'East of England',
    'Burnley': 'North west of England',
    'Nottingham Forest': 'Middle England',
    'Leicester City': 'Middle England',
    'Stoke City': 'Middle England',
    'Middlesbrough': 'North east of England',
    'Hull City': 'East of England',
    'Cardiff City': 'Wales',
    'Swansea City': 'Wales'
}

df["Opponent Detailed Region"] = df["Opponent"].map(opponent_detailed_region)

print(df.head())
# Out:
#    Season             Team Venue Result  GF (goals for)  GA (goals against)  \
# 0       1  Manchester City  Away      W               3                   0
# 1       1  Manchester City  Home      W               1                   0
# 2       1  Manchester City  Away      W               2                   1
# 3       1  Manchester City  Home      W               5                   1
# 4       1  Manchester City  Away      W               3                   1
#
#            Opponent  CrdY  CrdR  2CrdY  ...  xG (expected goals)  \
# 0           Burnley     0     0      0  ...                  1.9
# 1  Newcastle United     1     0      0  ...                  1.0
# 2  Sheffield United     0     0      0  ...                  3.5
# 3            Fulham     2     0      0  ...                  2.2
# 4   West Ham United     2     0      0  ...                  3.6
#
#    xGA (expected goals allowed)  Poss (possession)  Attendance  \
# ...

# %%
# A dictionary to map opponent teams in EPL to their broad region (same as the broad hometown of referee)
# Actually haven't been used in the code
opponent_region = {
    "Manchester City": "North England",
    "Arsenal": "South England",
    "Liverpool": "North England",
    "Aston Villa": "Midlands",
    "Tottenham Hotspur": "South England",
    "Chelsea": "South England",
    "Newcastle United": "North England",
    "Manchester United": "North England",
    "West Ham United": "South England",
    "Crystal Palace": "South England",
    "Brighton & Hove Albion": "South England",
    "Bournemouth": "South England",
    "Fulham": "South England",
    "Wolverhampton Wanderers": "Midlands",
    "Everton": "North England",
    "Brentford": "South England",
    "Nottingham Forest": "Midlands",
    "Luton Town": "Eastern England",
    "Burnley": "North England",
    "Sheffield United": "North England",
    "Leicester City": "Midlands",
    "Leeds United": "North England",
    "Southampton": "South England",
    "Watford": "Eastern England",
    "Norwich City": "Eastern England",
    "West Bromwich Albion": "Midlands",
    "Cardiff City": "Wales",
    "Huddersfield Town": "North England",
    "Swansea City": "Wales",
    "Stoke City": "Midlands",
    "Hull City": "North England",
    "Middlesbrough": "North England",
    "Sunderland": "North England",
    "Queens Park Rangers": "South England"
}

df["Opponent Region"] = df["Opponent"].map(opponent_region)

print(df.head())
# Out:
#    Season             Team Venue Result  GF (goals for)  GA (goals against)  \
# 0       1  Manchester City  Away      W               3                   0
# 1       1  Manchester City  Home      W               1                   0
# 2       1  Manchester City  Away      W               2                   1
# 3       1  Manchester City  Home      W               5                   1
# 4       1  Manchester City  Away      W               3                   1
#
#            Opponent  CrdY  CrdR  2CrdY  ...  xGA (expected goals allowed)  \
# 0           Burnley     0     0      0  ...                           0.3
# 1  Newcastle United     1     0      0  ...                           0.3
# 2  Sheffield United     0     0      0  ...                           0.7
# 3            Fulham     2     0      0  ...                           1.4
# 4   West Ham United     2     0      0  ...                           0.9
#
# ...
